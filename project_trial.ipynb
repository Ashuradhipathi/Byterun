# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashuradhipathi/Byterun/blob/main/project_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycocotools

# %%
data_dir = '/content/data'

# %%
train_images_url = 'http://images.cocodataset.org/zips/train2017.zip'
val_images_url = 'http://images.cocodataset.org/zips/val2017.zip'
train_annotations_url = 'http://images.cocodataset.org/annotations/annotations_trainval2017.zip'

# %%
# Create data directory
# !mkdir -p {data_dir}

# %%
# Download images and annotations
# !wget -c {train_images_url} -P {data_dir}
# !wget -c {val_images_url} -P {data_dir}
# !wget -c {train_annotations_url} -P {data_dir}
# Out:
# --2024-04-12 16:32:34--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 16.182.71.185, 3.5.1.206, 52.217.111.220, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|16.182.71.185|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘/content/data/train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  15.4MB/s    in 20m 14s
#
# 2024-04-12 16:52:48 (15.2 MB/s) - ‘/content/data/train2017.zip’ saved [19336861798/19336861798]
#
# --2024-04-12 16:52:48--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.194.129, 16.182.69.153, 52.217.205.193, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.194.129|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# ...

# %%
# !unzip -q {data_dir}/train2017.zip -d {data_dir}
# !unzip -q {data_dir}/val2017.zip -d {data_dir}
# !unzip -q {data_dir}/annotations_trainval2017.zip -d {data_dir}

# %%
# !zip -r data.zip data/
# Out:
#   adding: data/ (stored 0%)
#   adding: data/val2017.zip (stored 0%)
#   adding: data/annotations/ (stored 0%)
#   adding: data/annotations/instances_val2017.json (deflated 67%)
#   adding: data/annotations/person_keypoints_val2017.json (deflated 70%)
#   adding: data/annotations/instances_train2017.json (deflated 67%)
#   adding: data/annotations/captions_train2017.json (deflated 80%)
#   adding: data/annotations/captions_val2017.json (deflated 79%)
#   adding: data/annotations/person_keypoints_train2017.json (deflated 70%)
#   adding: data/train2017.zip (stored 0%)
#   adding: data/annotations_trainval2017.zip (stored 0%)
#   adding: data/train2017/ (stored 0%)
#   adding: data/train2017/000000149398.jpg (deflated 0%)
#   adding: data/train2017/000000445323.jpg (deflated 0%)
#   adding: data/train2017/000000192192.jpg (deflated 0%)
#   adding: data/train2017/000000313809.jpg (deflated 4%)
#   adding: data/train2017/000000163306.jpg (deflated 0%)
# ...
